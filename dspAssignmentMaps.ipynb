# %%
import folium
from branca.element import Figure

fig=Figure(height=400,width=1000)
map=folium.Map(location=[17.356914184411192, 82.53380835183141],tiles='Stamen Terrain',zoom_start=8)
fig.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coords1 = [[16.79504328286312, 80.83618799033785], [16.726665933522618, 80.90210596000144], [16.674051274455223, 80.94605127311047], [16.742447502458518, 81.0888735407149],
            [16.884422653532294, 81.32507959867604], [16.984267177434766, 81.47339503041908], [17.131309585624948, 81.94031398220274], [17.194292231996883, 82.09961574222307], 
           [17.25725346671985, 82.34131495404516], [17.325437217798292, 82.45667140095641], [17.404079330006375, 82.70386378719482], [17.466968675316544, 82.76978175685841],
           [17.51412143853749, 82.82471339824471], [17.6502716604711, 82.93457668101735], [17.707842751561873, 83.02246730723543], [17.75493264007195, 83.07190578448312],
           [17.911809298894873, 83.192755395533], [17.95361969149447, 83.22571438036479], [18.01109283894804, 83.26965969347384] ]

coords2 = [[16.787414049190115, 80.82265197591273], [16.687465639539543, 80.94899475110125], [16.740076601893623, 81.11378967526018], [17.097443846384135, 81.27858459941912],
           [16.966137708333985, 81.32252991252818], [16.950374785796903, 81.38844788219176], [17.03442840499896, 81.52577698565753], [17.029176158437114, 81.61366761187564],
           [17.029176158437114, 81.74550355120279], [17.155189283512964, 82.01466858432707],
           [17.270626225098226, 82.36623107519131], [17.349291821638378, 82.45961486554805], [17.647912357489382, 82.60243713315245], [17.632207747474546, 82.86061584766813],
           [17.647912357489382, 82.9100543249158], [17.851947292428274, 83.24513733737231], [17.914680355328223, 83.40993226153125], [18.07141575513016, 83.37148011256085],
           [18.03485662570574, 83.2780963222041], [18.01109283894804, 83.26965969347384]]


f1=folium.FeatureGroup("my village way")
line=folium.vector_layers.PolyLine(coords1,popup='<b>Path to my village</b>',tooltip='Way1',color='blue',weight=4).add_to(f1)

f2=folium.FeatureGroup("my village way2")
line1=folium.vector_layers.PolyLine(coords2,popup='<b>Path to my village2</b>',tooltip='Way2',color='orange',weight=4).add_to(f2)

f1.add_to(map)
f2.add_to(map)
folium.LayerControl().add_to(map)


folium.Marker(location=[18.01109283894804, 83.26965969347384],popup='Kothavalasa',tooltip='HOME',icon=folium.Icon(color='darkpurple',prefix = 'fa', icon='fa-flag-checkered')).add_to(map)
folium.Marker(location=[16.798897281055517, 80.84598354338551],popup='Start',tooltip='NUZVID',icon=folium.Icon(color='yellow',prefix = 'fa', icon='fa-flag')).add_to(map)
folium.Marker(location=[16.712669253961526, 81.094027782646],popup='bank',tooltip='Bank',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-building')).add_to(map)
folium.Marker(location=[16.886664887450106, 81.32195332325992],popup='restaurant',tooltip='restaurants',icon=folium.Icon(color='green',prefix = 'fa', icon='fa-coffee')).add_to(map)
folium.Marker(location=[17.28317132882947, 82.39643867591262],popup='hotel',tooltip='HOTEL',icon=folium.Icon(color='darkgreen',prefix='fa',icon='fa-bed')).add_to(map)

folium.Marker(location=[16.877788976914825, 81.26974954362714],popup='hospital',tooltip='HOSPITAL',icon=folium.Icon(color='darkgreen',prefix='fa',icon='fa-bed')).add_to(map)
folium.Marker(location=[17.39857431962176, 82.66736893792591],popup='Post office',tooltip='Post_Office',icon=folium.Icon(color='orange',prefix='fa',icon='fa-book')).add_to(map)
folium.Marker(location=[17.39857431962176, 82.66736893792591],popup='Post office',tooltip='Post_Office',icon=folium.Icon(color='orange',prefix='fa',icon='fa-book')).add_to(map)
folium.Marker(location=[17.70059779825252, 83.00858104841662],popup='Railway station',tooltip='RAILWAY STATION',icon=folium.Icon(color='cadetblue',prefix='fa',icon='fa-subway')).add_to(map)




map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: color argument of Icon should be one of: {'darkgreen', 'white', 'cadetblue', 'green', 'orange', 'pink', 'blue', 'lightgreen', 'gray', 'darkpurple', 'red', 'darkred', 'beige', 'darkblue', 'purple', 'lightgray', 'black', 'lightred', 'lightblue'}.
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
